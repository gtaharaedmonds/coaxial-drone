# %% [markdown]
# ### Load .mat file

# %%
import matplotlib.pyplot as plt
from src.log_analysis import Log

FILE_PATH = "mat_files/00000016.BIN-580150.mat"
log = Log(FILE_PATH)
# Out:
# c:\Users\gtaha\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\io\matlab\mio.py:226: MatReadWarning: Duplicate variable name "BCL_label" in stream - replacing previous with new
# Consider mio5.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)
# c:\Users\gtaha\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\io\matlab\mio.py:226: MatReadWarning: Duplicate variable name "ISBD_label" in stream - replacing previous with new
# Consider mio5.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)
# c:\Users\gtaha\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\io\matlab\mio.py:226: MatReadWarning: Duplicate variable name "XKF4_label" in stream - replacing previous with new
# Consider mio5.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)
# ...

# %% [markdown]
# ### Print all msg

# %%
log.print_msgs()
# Out:
# __header__
# __version__
# __globals__
# FMT_label
# UNIT_label
# FMTU_label
# MULT_label
# GPS_label
# GPA_label
# UBX1_label
# UBX2_label
# GRAW_label
# GRXH_label
# GRXS_label
# SBPH_label
# SBRH_label
# SBRM_label
# SBRE_label
# MSG_label
# RCIN_label
# RCI2_label
# RCOU_label
# RCO2_label
# RCO3_label
# RSSI_label
# BARO_label
# PL_label
# POWR_label
# CMD_label
# MAVC_label
# RAD_label
# CAM_label
# TRIG_label
# ARSP_label
# BAT_label
# BCL_label
# MAG_label
# MODE_label
# RFND_label
# DMS_label
# BCN_label
# PM_label
# SRTL_label
# OABR_label
# OADJ_label
# SA_label
# OAVG_label
# SIM_label
# TERR_label
# ESC_label
# CSRV_label
# PIDR_label
# PIDP_label
# PIDY_label
# PIDA_label
# PIDS_label
# PIDN_label
# PIDE_label
# DSTL_label
# ACC_label
# GYR_label
# IMU_label
# VIBE_label
# ISBH_label
# ISBD_label
# RFRH_label
# RFRF_label
# RFRN_label
# REV2_label
# RSO2_label
# RWA2_label
# REV3_label
# RSO3_label
# RWA3_label
# REY3_label
# RISH_label
# RISI_label
# RASH_label
# ...

# %% [markdown]
# ### Print signal labels from a msg

# %%
# Print labels for an ex. message
log.print_labels("BAT_label")
# Out:
# 0: LineNo
# 1: TimeUS
# 2: Instance
# 3: Volt
# 4: VoltR
# 5: Curr
# 6: CurrTot
# 7: EnrgTot
# 8: Temp
# 9: Res
# 10: RemPct

# %% [markdown]
# ### Get data by name and plot

# %%
time_series = log.get_data("BAT_label", "BAT_0", "Curr", start=555)
plt.plot(*time_series)
# Out:
# [  1016.   1295.   1490. ... 580067. 580093. 580122.]
